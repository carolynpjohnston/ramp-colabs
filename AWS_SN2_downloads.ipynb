# %% [markdown]
# ### Download SpaceNet-2 data from AWS S3 for access in Google Colab.

# %% [markdown]
# First, get access to your google drive (for carolyn.p.johnston@gmail.com).
#
# You'll have to enter an authorization code in this window every time.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Now get access to the S3 drive where the SN2 data is.
# First you need to pip install awscli (AWS command line interface) so you can run AWS commands in this notebook instance.
# It reports an error, but after this command runs, awscli is accessible, so what the heck.

# %%
# !pip install awscli
# Out:
# ...
#      |████████████████████████████████| 3.7 MB 2.7 MB/s
# ...
#      |████████████████████████████████| 79 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 7.9 MB 40.9 MB/s
# ...
#      |████████████████████████████████| 547 kB 43.4 MB/s
# ...
#      |████████████████████████████████| 138 kB 65.6 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.6 which is incompatible.
# ...

# %% [markdown]
# You'll need your AWS access and secret access key ids to access S3. If you're changing your auth keys, you'll need to run this block of code; but the auth file is stored on your google drive, so if the keys are unchanged, this block doesn't need to run.

# %%
# to my amazement, the code below actually worked, which means the google drive connection is working. 
# This script only needed to be
# run once to place the ini file. 

# UNCOMMENT IF YOU NEED TO UPDATE YOUR AWS CREDENTIALS.

# text = '''
# [default]
# aws_access_key_id = AKIA4CPQKULFL4SWZM4N 
# aws_secret_access_key = aws_secret_access_key_here
# region = us-west-2
# '''

# path = "/content/drive/My Drive/config/awscli.ini"
# with open(path, 'w') as f:
#    f.write(text)
# !cat /content/drive/My\ Drive/config/awscli.ini

# %%
# pass in information about the credentials file
import os
# !export AWS_SHARED_CREDENTIALS_FILE=/content/drive/My\ Drive/config/awscli.ini
path = "/content/drive/My Drive/config/awscli.ini"
os.environ['AWS_SHARED_CREDENTIALS_FILE'] = path
print(os.environ['AWS_SHARED_CREDENTIALS_FILE'])
# Out:
# /content/drive/My Drive/config/awscli.ini

# %% [markdown]
# Now, we should be connected to AWS S3, so let's try seeing if we can see the SN2 data. Yes, we can... it's huge.

# %%
# also to my amazement, I got connected.
# !aws s3 ls s3://spacenet-dataset/spacenet/SN2_buildings/tarballs --recursive --human-readable --summarize
# Out:
# 2019-11-07 14:03:16    7.9 GiB spacenet/SN2_buildings/tarballs/AOI_2_Vegas_Test_public.tar.gz
# 2019-11-07 14:03:16    1.8 GiB spacenet/SN2_buildings/tarballs/AOI_3_Paris_Test_public.tar.gz
# 2019-11-07 14:03:16    7.7 GiB spacenet/SN2_buildings/tarballs/AOI_4_Shanghai_Test_public.tar.gz
# 2019-11-07 14:03:16    1.6 GiB spacenet/SN2_buildings/tarballs/AOI_5_Khartoum_Test_public.tar.gz
# 2019-11-05 19:30:54   23.9 GiB spacenet/SN2_buildings/tarballs/SN2_buildings_train_AOI_2_Vegas.tar.gz
# 2019-11-05 19:31:37    5.3 GiB spacenet/SN2_buildings/tarballs/SN2_buildings_train_AOI_3_Paris.tar.gz
# 2019-11-05 19:32:40   23.4 GiB spacenet/SN2_buildings/tarballs/SN2_buildings_train_AOI_4_Shanghai.tar.gz
# 2019-11-05 19:33:56    4.7 GiB spacenet/SN2_buildings/tarballs/SN2_buildings_train_AOI_5_Khartoum.tar.gz
#
# Total Objects: 8
#    Total Size: 76.3 GiB

# %%
# Uncomment to extract a file by name, as a test of connection.
#!cd /content/drive/MyDrive/SN2/Khartoum; aws s3 cp s3://spacenet-dataset/spacenet/SN2_buildings/tarballs/SN2_buildings_train_AOI_5_Khartoum.tar.gz SN2_buildings_train_AOI_5_Khartoum.tar.gz
# Out:
# download: s3://spacenet-dataset/spacenet/SN2_buildings/tarballs/SN2_buildings_train_AOI_5_Khartoum.tar.gz to ./SN2_buildings_train_AOI_5_Khartoum.tar.gz

# %%
# move the Khartoum data to its home location on your drive.
# !ls
# !mv SN2_buildings_train_AOI_5_Khartoum.tar.gz /content/drive/MyDrive/SN2/Khartoum
# Out:
# drive  sample_data  SN2_buildings_train_AOI_5_Khartoum.tar.gz.Af8DBe52

# %%
# alternatively, copy to its home location in one step
# !cd drive/MyDrive/SN2/Khartoum; aws s3 cp s3://spacenet-dataset/spacenet/SN2_buildings/tarballs/AOI_5_Khartoum_Test_public.tar.gz .
# Out:
# download: s3://spacenet-dataset/spacenet/SN2_buildings/tarballs/AOI_5_Khartoum_Test_public.tar.gz to ./AOI_5_Khartoum_Test_public.tar.gz

# %%
# we are currently in the 'content' drive by default
# in the above two cells, I did successfully download the Khartoum data. 
# !ls drive/MyDrive/SN2/Khartoum
# Out:
# AOI_5_Khartoum_Test_public.tar.gz  SN2_buildings_train_AOI_5_Khartoum.tar
# AOI_5_Khartoum_Train

# %%
# NTS: this demonstrates that bucket names are defined without the s3 prefix.
# !aws s3api get-bucket-acl --bucket spacenet-dataset
# Out:
# {
#     "Owner": {
#         "DisplayName": "todd.bacastow",
#         "ID": "aa8c72b923fc3c3c17b1e7ae896283a6ea7b8e7e838abd9b1d313e9657317c19"
#     },
#     "Grants": [
#         {
#             "Grantee": {
#                 "DisplayName": "todd.bacastow",
#                 "ID": "aa8c72b923fc3c3c17b1e7ae896283a6ea7b8e7e838abd9b1d313e9657317c19",
#                 "Type": "CanonicalUser"
#             },
#             "Permission": "READ"
#         },
#         {
#             "Grantee": {
#                 "DisplayName": "todd.bacastow",
#                 "ID": "aa8c72b923fc3c3c17b1e7ae896283a6ea7b8e7e838abd9b1d313e9657317c19",
#                 "Type": "CanonicalUser"
#             },
#             "Permission": "WRITE"
#         },
#         {
#             "Grantee": {
#                 "DisplayName": "todd.bacastow",
#                 "ID": "aa8c72b923fc3c3c17b1e7ae896283a6ea7b8e7e838abd9b1d313e9657317c19",
#                 "Type": "CanonicalUser"
#             },
# ...
